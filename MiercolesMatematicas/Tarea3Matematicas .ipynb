# %%
import matplotlib.pyplot as plt
import numpy as np
import math
from PIL import Image
from mpl_toolkits import mplot3d

# %% [markdown]
# Ejercico 1

# %%
print("3x + 2y = 6\n6x + 4y = −9\n")
A = np.array([[3,2],[6,4]])
B = np.array([6,-9])

x = np.linspace(-3,6)
lines = plt.plot(x,(6-3*x)/2,x,(-9-6*x)/4)
# Out:
# 3x + 2y = 6
# 6x + 4y = −9

# %%
print("x + y = 3\nx - 4y = 1\n")
A = np.array([[1,1],[1,-4]])
B = np.array([3,1])

x = np.linspace(-3,6)
lines = plt.plot(x,(3-x),x,(1-x)/-4)
# Out:
# x + y = 3
# x - 4y = 1

# %%
print("2x − y + 2z = 3\n2x + 3y − z = 0\nx + 2y + 2z = −12")
y = np.linspace(-3, 6)
x2, y2 = np.meshgrid(x, y)
z1 = (3-2*x2+y2)/2
z2 = (-2*x2-3*y2)/-1
z3 = (-12-x2-2*y2)/2
fig = plt.figure()
ax = fig.add_subplot(projection="3d") 
ax.plot_surface(x2, y2, z1)
ax.plot_surface(x2, y2, z2)
ax.plot_surface(x2, y2, z3)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
ax.set_title("SISTEMA DE ECUACIONES 3")
# Out:
# 2x − y + 2z = 3
# 2x + 3y − z = 0
# x + 2y + 2z = −12
# Text(0.5, 0.92, 'SISTEMA DE ECUACIONES 3')

# %% [markdown]
# Ejercicio 2

# %%
def f(x):
    return x**2+3

# %%
print("y = x^2 + 3")

print("Recta Tangente: y = 2x + 2")

x = np.linspace (-3.0,3.0)
lines = plt.plot(x,f(x),x,2*x+2)
plt.plot(1,4,'o',color = 'red')
plt.grid(True)
plt.ylim(0,10)
plt.show()
# Out:
# y = x^2 + 3
# Recta Tangente: y = 2x + 2

# %% [markdown]
# Ejercicio 3

# %%
lines=plt.plot(x,(x**2)+3,x,4.6055*x -2.30275,x,-2.6055*x + 1.30275)
plt.plot(0.5,0,'o',color='blue')
plt.plot(-1.30275 , 4.69715,'o', color = 'red')
plt.plot(2.30275,8.30256,'o', color = 'red')
plt.grid(True)
plt.ylim(-1,30)
plt.xlim(-10,10)
plt.show()

# %%
#SOLUCIÓN PROPUESTA EN CLASE
x = np.linspace(0,3)
fig, ax = plt.subplots()
y = x**2 +3
l1 = ax.plot(x,y,'-', color = 'blue')
ax.scatter(.5,0, color = 'red')
ax.grid(True)

indice = 0
for i in x[5:40]:
    m = 2*i
    ax.plot(x,m*x-(m*x[indice])+y[indice],'-',color = 'orange')
    indice+=1

# %% [markdown]
# Ejercico 4

# %%
def funcion(x):
    y=x**3-x**2-2*x
    return y

# %%
x = np.linspace(-1,6)
r = (funcion(3)-funcion(1))/(3-1)
print(r)
print(np.roots([3,-2,-9])) #raiz de cualquier Polinomio 
y=x**3-x**2-2*x
fig,ax = plt.subplots() 
l1=ax.plot(x,y,'-',color='green')
l2=ax.plot(x,7*x-9,'-',color='blue')
l3=ax.plot(x,7*x-14.05,'-',color='red')
# Out:
# 7.0
# [ 2.09716754 -1.43050087]
